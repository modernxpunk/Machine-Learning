# %%
import pandas as pd

# %%
# data = pd.DataFrame()

# data = pd.DataFrame(['Name', 'Age', 'Country', 'Hobby'])

# data = pd.DataFrame({
#      'Name': ['Tom', 'Joseph', 'Krish'],
#      'Age': [20, 21, 31]
# })

# data = pd.DataFrame({
#     'Name': ['Tom', 'Joseph', 'Krish'],
#     'Age': [20, 21, 31]
# }, index=['№1','№2','№3'])

# data = pd.DataFrame(
#     list(zip(
#         ['Tom', 'Joseph', 'Krish'],
#         [20, 21, 31]
#     )), columns=["№1", "№2"])

# %%
data = pd.read_csv('oscar_age_male.csv')
data.keys()
# Out:
# Index(['Index', 'Year', 'Age', 'Name', 'Movie'], dtype='object')

# %%
data.describe()
# Out:
#            Index         Year        Age
# count  89.000000    89.000000  89.000000
# mean   45.000000  1972.000000  43.876404
# std    25.836021    25.836021   8.818653
# min     1.000000  1928.000000  29.000000
# 25%    23.000000  1950.000000  38.000000
# 50%    45.000000  1972.000000  42.000000
# 75%    67.000000  1994.000000  49.000000
# max    89.000000  2016.000000  76.000000

# %%
data.head(3)
# Out:
#    Index  Year  Age           Name                                   Movie
# 0      1  1928   44  Emil Jannings  The Last Command, The Way of All Flesh
# 1      2  1929   41  Warner Baxter                          In Old Arizona
# 2      3  1930   62  George Arliss                                Disraeli

# %%
data.tail(4)
# Out:
#     Index  Year  Age                 Name                     Movie
# 85     86  2013   55     Daniel Day-Lewis                   Lincoln
# 86     87  2014   44  Matthew McConaughey        Dallas Buyers Club
# 87     88  2015   33       Eddie Redmayne  The Theory of Everything
# 88     89  2016   41    Leonardo DiCaprio              The Revenant

# %%
data.iloc[2: 5]
# Out:
#    Index  Year  Age              Name        Movie
# 2      3  1930   62     George Arliss     Disraeli
# 3      4  1931   53  Lionel Barrymore  A Free Soul
# 4      5  1932   47     Wallace Beery    The Champ

# %%
data.sample(n=4)
# Out:
#     Index  Year  Age              Name         Movie
# 3       4  1931   53  Lionel Barrymore   A Free Soul
# 81     82  2009   48         Sean Penn          Milk
# 17     18  1945   41       Bing Crosby  Going My Way
# 43     44  1971   43   George C. Scott        Patton

# %%
data.sample(frac=0.5)
# Out:
#     Index  Year  Age                 Name  \
# 11     12  1939   38        Spencer Tracy
# 38     39  1966   42           Lee Marvin
# 26     27  1954   35       William Holden
# 65     66  1993   52            Al Pacino
# 70     71  1998   60       Jack Nicholson
# 10     11  1938   37        Spencer Tracy
# 83     84  2011   50          Colin Firth
# 51     52  1979   40           Jon Voight
# 41     42  1969   45      Cliff Robertson
# 84     85  2012   39        Jean Dujardin
# 2       3  1930   62        George Arliss
# 30     31  1958   43        Alec Guinness
# 14     15  1942   40          Gary Cooper
# 32     33  1960   36      Charlton Heston
# 81     82  2009   48            Sean Penn
# 19     20  1947   49        Fredric March
# 22     23  1950   38   Broderick Crawford
# 28     29  1956   39      Ernest Borgnine
# 12     13  1940   34         Robert Donat
# 9      10  1937   41            Paul Muni
# 45     46  1973   48        Marlon Brando
# ...

# %%
data.drop_duplicates()
# Out:
#     Index  Year  Age                 Name  \
# 0       1  1928   44        Emil Jannings
# 1       2  1929   41        Warner Baxter
# 2       3  1930   62        George Arliss
# 3       4  1931   53     Lionel Barrymore
# 4       5  1932   47        Wallace Beery
# ..    ...   ...  ...                  ...
# 84     85  2012   39        Jean Dujardin
# 85     86  2013   55     Daniel Day-Lewis
# 86     87  2014   44  Matthew McConaughey
# 87     88  2015   33       Eddie Redmayne
# 88     89  2016   41    Leonardo DiCaprio
#
#                                      Movie
# 0   The Last Command, The Way of All Flesh
# 1                           In Old Arizona
# 2                                 Disraeli
# 3                              A Free Soul
# 4                                The Champ
# ..                                     ...
# 84                              The Artist
# 85                                 Lincoln
# 86                      Dallas Buyers Club
# ...

# %%
data.keys()
# Out:
# Index(['Index', 'Year', 'Age', 'Name', 'Movie'], dtype='object')

# %%
data.nlargest(5, 'Year')
# Out:
#     Index  Year  Age                 Name                     Movie
# 88     89  2016   41    Leonardo DiCaprio              The Revenant
# 87     88  2015   33       Eddie Redmayne  The Theory of Everything
# 86     87  2014   44  Matthew McConaughey        Dallas Buyers Club
# 85     86  2013   55     Daniel Day-Lewis                   Lincoln
# 84     85  2012   39        Jean Dujardin                The Artist

# %%
data.nsmallest(3, 'Age')
# Out:
#     Index  Year  Age              Name              Movie
# 75     76  2003   29      Adrien Brody        The Pianist
# 27     28  1955   30     Marlon Brando  On the Waterfront
# 50     51  1978   30  Richard Dreyfuss   The Goodbye Girl

# %%
data[['Name', 'Age', 'Year']]
# Out:
#                    Name  Age  Year
# 0         Emil Jannings   44  1928
# 1         Warner Baxter   41  1929
# 2         George Arliss   62  1930
# 3      Lionel Barrymore   53  1931
# 4         Wallace Beery   47  1932
# ..                  ...  ...   ...
# 84        Jean Dujardin   39  2012
# 85     Daniel Day-Lewis   55  2013
# 86  Matthew McConaughey   44  2014
# 87       Eddie Redmayne   33  2015
# 88    Leonardo DiCaprio   41  2016
#
# [89 rows x 3 columns]

# %%
data[data['Age'] > 60]
# Out:
#     Index  Year  Age           Name               Movie
# 2       3  1930   62  George Arliss            Disraeli
# 42     43  1970   62     John Wayne           True Grit
# 54     55  1982   76    Henry Fonda      On Golden Pond
# 59     60  1987   62    Paul Newman  The Color of Money

# %%
data.plot.scatter('Year', 'Age')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Age'>

# %%
data.min()
# Out:
# Index                1
# Year              1928
# Age                 29
# Name      Adrien Brody
# Movie    A Double Life
# dtype: object

# %%
data.max()
# Out:
# Index                     89
# Year                    2016
# Age                       76
# Name             Yul Brynner
# Movie    Yankee Doodle Dandy
# dtype: object

# %%
data.sum()
# Out:
# Index                                                 4005
# Year                                                175508
# Age                                                   3905
# Name     Emil JanningsWarner BaxterGeorge ArlissLionel ...
# Movie    The Last Command, The Way of All FleshIn Old A...
# dtype: object

# %%
data.median()
# Out:
# /tmp/ipykernel_22871/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Index      45.0
# Year     1972.0
# Age        42.0
# dtype: float64

# %%
data.count()
# Out:
# Index    89
# Year     89
# Age      89
# Name     89
# Movie    89
# dtype: int64

# %%
data.std()
# Out:
# /tmp/ipykernel_22871/2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Index    25.836021
# Year     25.836021
# Age       8.818653
# dtype: float64

# %%
data.var()
# Out:
# /tmp/ipykernel_22871/445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# Index    667.500000
# Year     667.500000
# Age       77.768641
# dtype: float64

# %%
data.mean()
# Out:
# /tmp/ipykernel_22871/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Index      45.000000
# Year     1972.000000
# Age        43.876404
# dtype: float64

# %%
def isAgeOdd(n):
    return n % 2 

data['Age'].apply(isAgeOdd)
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
#      ..
# 84    1
# 85    1
# 86    0
# 87    1
# 88    1
# Name: Age, Length: 89, dtype: int64
