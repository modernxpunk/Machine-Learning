# %%
import pandas as pd

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis  
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.naive_bayes import GaussianNB  
from sklearn.tree import DecisionTreeClassifier  
from sklearn.svm import SVC

import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('practice1_data.csv')

# %%
data
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 0     2.163950  0.015729 -1.136593  2.182571 -1.552051 -0.909067  1.791084
# 1     1.364464 -1.359741 -1.881798 -0.484231 -1.974301 -0.017010  2.184909
# 2     1.237133  0.945965 -0.008633  0.889645  0.348132 -1.863290 -1.093229
# 3     0.530019  2.739019  1.168152 -0.182967 -0.313546  1.274500  1.097952
# 4    -1.169403 -0.387841  0.049067 -2.136358 -1.839488 -0.635955 -0.136341
# ...        ...       ...       ...       ...       ...       ...       ...
# 1495 -0.146574 -3.057110 -1.292373 -1.313307  0.393876 -1.177190  0.201903
# 1496  1.436362 -0.860712 -0.236148  0.034834 -1.078734  0.836675  2.494351
# 1497  1.030032 -2.748605 -1.579382  0.594056 -0.187863 -1.017196 -0.264793
# 1498  1.681369 -1.353401  0.479499  0.189862  0.234857  1.408110 -1.642835
# 1499 -0.571404  0.737915 -0.347353  1.309141 -0.451142  0.052095  0.076439
#
#             x8        x9       x10  classes
# ...

# %%
features = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10']

# %%
X = data[features]
y = data['classes']

# %%
model_LinearDiscriminantAnalysis = LinearDiscriminantAnalysis()
model_KNeighborsClassifier = KNeighborsClassifier()
model_GaussianNB = GaussianNB()
model_DecisionTreeClassifier = DecisionTreeClassifier()
model_SVC = SVC()

# %%
model_LinearDiscriminantAnalysis.fit(X, y)
model_KNeighborsClassifier.fit(X, y)
model_GaussianNB.fit(X, y)
model_DecisionTreeClassifier.fit(X, y)
model_SVC.fit(X, y)
# Out:
# SVC()

# %%
original = y
sample = len(original)

# %%
ldAnalysis = tuple(np.array(model_LinearDiscriminantAnalysis.predict(X)))
KNN = tuple(np.array(model_KNeighborsClassifier.predict(X)))
Gaussian = tuple(np.array(model_GaussianNB.predict(X)))
dTree = tuple(np.array(model_DecisionTreeClassifier.predict(X)))
SVC = tuple(np.array(model_SVC.predict(X)))

# %%
percent_of_correct_answer = {ldAnalysis: 0, KNN: 0, Gaussian: 0, dTree: 0, SVC: 0}

for model in percent_of_corrent_answer:
    count_corrent_classes = np.size(np.where(model == original))
    percent_of_correct_answer[model] = count_corrent_classes / sample

print(percent_of_correct_answer.values())
# Out:
# dict_values([0.6146666666666667, 0.854, 0.6226666666666667, 1.0, 0.8526666666666667])

# %%
# 1 DecisionTreeClassifier     100%
# 3 KNeighborsClassifier       85.4%
# 2 SVC                        85.267%
# 4 GaussianNB                 62.267%
# 5 LinearDiscriminantAnalysis 61.467%
